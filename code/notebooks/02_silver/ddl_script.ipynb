# %% [markdown]
# - Create spark session and the silver schema if it does not exist in the "teleco_churn_datalakehouse"  catalogue

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS teleco_churn_datalakehouse.silver
