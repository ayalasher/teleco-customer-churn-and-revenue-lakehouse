# %% [markdown]
# - Data definition file for the gold layer

# %% [markdown]
# - Creating the gold schema if it does not exist

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS teleco_churn_datalakehouse.gold
