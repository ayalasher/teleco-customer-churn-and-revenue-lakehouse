# %% [markdown]
# ## bronze ddl and loading script

# %% [markdown]
# #### Creating the schema if it does not exist.

# %%
# %sql
CREATE CATALOG IF NOT EXISTS teleco_churn_datalakehouse

# %% [markdown]
# ### Creating the "bronze" schema if it does not exist in the "teleco_churn_datalakehouse" catalogue

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS teleco_churn_datalakehouse.bronze
